# %%
# Importing the libraries 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import json
from scipy import stats

# %%
with open (r"C:\Users\Ritesh Reddy\OneDrive\Desktop\campaign\campaign.json") as f:
    data_1=json.load(f)

# %%
with open (r"C:\Users\Ritesh Reddy\OneDrive\Desktop\behaviour\behaviour.json") as f:
    data=json.load(f)

# %%
formatted_data = []
for item in data_1:
    for key, value in item.items():
        value['CustomerID'] = key  
        formatted_data.append(value)


campaign = pd.DataFrame(formatted_data)


campaign = campaign[['CustomerID', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain']]

# %%
formatted_data_1 = []
for item in data:
    for key, value in item.items():
        value['CustomerID'] = key 
        formatted_data_1.append(value)


behaviour = pd.DataFrame(formatted_data_1)


behaviour = behaviour[['CustomerID', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds','NumDealsPurchases','NumWebPurchases','NumCatalogPurchases','NumStorePurchases','NumWebVisitsMonth']]

# %%
campaign=pd.DataFrame(campaign)

# %%
behaviour = pd.DataFrame(behaviour)

# %%
campaign.head()
# Out:
#   CustomerID  AcceptedCmp1  AcceptedCmp2  AcceptedCmp3  AcceptedCmp4  \
# 0    ID_1826             0             0             0             0
# 1       ID_1             0             1             0             0
# 2   ID_10476             0             0             0             0
# 3    ID_1386             0             0             0             0
# 4    ID_5371             0             0             1             0
#
#    AcceptedCmp5  Response  Complain
# 0             0         1         0
# 1             0         1         0
# 2             0         0         0
# 3             0         0         0
# 4             0         1         0

# %%
behaviour.head()
# Out:
#   CustomerID  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0    ID_1826        0       189        104              379              111
# 1       ID_1        0       464          5               64                7
# 2   ID_10476        0       134         11               59               15
# 3    ID_1386        0        10          0                1                0
# 4    ID_5371        0         6         16               24               11
#
#    MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0               189           218                  1                4
# 1                 0            37                  1                7
# 2                 2            30                  1                3
# 3                 0             0                  1                1
# 4                 0            34                  2                3
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth
# 0                    4                  6                  1
# 1                    3                  7                  5
# 2                    2                  5                  2
# 3                    0                  2                  7
# 4                    1                  2                  7

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %%
demographics=pd.read_csv(r"C:\Users\Ritesh Reddy\OneDrive\Desktop\Retail_Sales_ABADS\demographics.txt",delimiter="\t")

# %%
demographics.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer Country
# 0         0     6/16/14      SP
# 1         0     6/15/14      CA
# 2         1     5/13/14      US
# 3         1     5/11/14     AUS
# 4         0      4/8/14      SP

# %%
demographics['CustomerID']=demographics['ID']

# %%
demographics.drop(columns=['ID'], inplace=True)

# %%
demographics['Customer_Inseption_Date'] = pd.to_datetime(demographics['Dt_Customer'], format='mixed')

# %%
demographics.drop(columns=['Dt_Customer'], inplace=True)

# %%
demographics=demographics.dropna()
demographics.isnull().sum()
# Out:
# Year_Birth                 0
# Education                  0
# Marital_Status             0
#  Income                    0
# Kidhome                    0
# Teenhome                   0
# Country                    0
# CustomerID                 0
# Customer_Inseption_Date    0
# dtype: int64

# %%
demographics.columns = demographics.columns.str.strip()

# %%
demographics['Income'] = demographics['Income'].str.strip()

# %%
demographics.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Country', 'CustomerID', 'Customer_Inseption_Date'],
#       dtype='object')

# %%
demographics['Income(in_$)'] = demographics['Income'].str.replace('$', '').str.replace(',','').astype(float)

# %%
demographics.drop(columns=['Income'], inplace=True)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %%
campaign_behaviour=pd.merge(campaign,behaviour,on='CustomerID')

# %%
campaign_behaviour.head()
# Out:
#   CustomerID  AcceptedCmp1  AcceptedCmp2  AcceptedCmp3  AcceptedCmp4  \
# 0    ID_1826             0             0             0             0
# 1       ID_1             0             1             0             0
# 2   ID_10476             0             0             0             0
# 3    ID_1386             0             0             0             0
# 4    ID_5371             0             0             1             0
#
#    AcceptedCmp5  Response  Complain  Recency  MntWines  MntFruits  \
# 0             0         1         0        0       189        104
# 1             0         1         0        0       464          5
# 2             0         0         0        0       134         11
# 3             0         0         0        0        10          0
# 4             0         1         0        0         6         16
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0              379              111               189           218
# 1               64                7                 0            37
# 2               59               15                 2            30
# 3                1                0                 0             0
# 4               24               11                 0            34
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  1                4                    4                  6
# 1                  1                7                    3                  7
# 2                  1                3                    2                  5
# 3                  1                1                    0                  2
# 4                  2                3                    1                  2
#
#    NumWebVisitsMonth
# 0                  1
# 1                  5
# 2                  2
# 3                  7
# 4                  7

# %%
campaign_behaviour[["CustomerID","CustomerID"]]=campaign_behaviour['CustomerID'].str.split('_', expand=True)

# %%
campaign_behaviour["CustomerID"]=campaign_behaviour["CustomerID"].astype(int)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %%
w_data=pd.merge(campaign_behaviour,demographics,on='CustomerID')

# %%
w_data.head()
# Out:
#    CustomerID  AcceptedCmp1  AcceptedCmp2  AcceptedCmp3  AcceptedCmp4  \
# 0        1826             0             0             0             0
# 1           1             0             1             0             0
# 2       10476             0             0             0             0
# 3        1386             0             0             0             0
# 4        5371             0             0             1             0
#
#    AcceptedCmp5  Response  Complain  Recency  MntWines  ...  \
# 0             0         1         0        0       189  ...
# 1             0         1         0        0       464  ...
# 2             0         0         0        0       134  ...
# 3             0         0         0        0        10  ...
# 4             0         1         0        0         6  ...
#
#    NumStorePurchases  NumWebVisitsMonth  Year_Birth   Education  \
# 0                  6                  1        1970  Graduation
# 1                  7                  5        1961  Graduation
# 2                  5                  2        1958  Graduation
# 3                  2                  7        1967  Graduation
# 4                  2                  7        1989  Graduation
#
#    Marital_Status  Kidhome  Teenhome  Country  Customer_Inseption_Date  \
# 0        Divorced        0         0       SP               2014-06-16
# 1          Single        0         0       CA               2014-06-15
# 2         Married        0         1       US               2014-05-13
# 3        Together        1         1      AUS               2014-05-11
# 4          Single        1         0       SP               2014-04-08
#
#    Income(in_$)
# 0       84835.0
# 1       57091.0
# 2       67267.0
# 3       32474.0
# 4       21474.0
#
# [5 rows x 28 columns]

# %%
w_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216 entries, 0 to 2215
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CustomerID               2216 non-null   int32
#  1   AcceptedCmp1             2216 non-null   int64
#  2   AcceptedCmp2             2216 non-null   int64
#  3   AcceptedCmp3             2216 non-null   int64
#  4   AcceptedCmp4             2216 non-null   int64
#  5   AcceptedCmp5             2216 non-null   int64
#  6   Response                 2216 non-null   int64
#  7   Complain                 2216 non-null   int64
#  8   Recency                  2216 non-null   int64
#  9   MntWines                 2216 non-null   int64
#  10  MntFruits                2216 non-null   int64
#  11  MntMeatProducts          2216 non-null   int64
#  12  MntFishProducts          2216 non-null   int64
#  13  MntSweetProducts         2216 non-null   int64
#  14  MntGoldProds             2216 non-null   int64
#  15  NumDealsPurchases        2216 non-null   int64
#  16  NumWebPurchases          2216 non-null   int64
#  17  NumCatalogPurchases      2216 non-null   int64
#  18  NumStorePurchases        2216 non-null   int64
#  19  NumWebVisitsMonth        2216 non-null   int64
#  20  Year_Birth               2216 non-null   int64
#  21  Education                2216 non-null   object
#  22  Marital_Status           2216 non-null   object
#  23  Kidhome                  2216 non-null   int64
#  24  Teenhome                 2216 non-null   int64
#  25  Country                  2216 non-null   object
#  26  Customer_Inseption_Date  2216 non-null   datetime64[ns]
#  27  Income(in_$)             2216 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(22), object(3)
# memory usage: 476.2+ KB

# %%
w_data['Education'].value_counts()
# Out:
# Education
# Graduation    1116
# PhD            481
# Master         365
# 2n Cycle       200
# Basic           54
# Name: count, dtype: int64

# %%
w_data['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     857
# Together    573
# Single      471
# Divorced    232
# Widow        76
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64

# %%
w_data['Country'].value_counts()
# Out:
# Country
# SP     1093
# SA      337
# CA      266
# AUS     147
# IND     147
# GER     116
# US      107
# ME        3
# Name: count, dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %%
count=w_data.select_dtypes(include=np.number)
cat=w_data.select_dtypes(include=object)

# %%
count.columns
# Out:
# Index(['CustomerID', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'Year_Birth', 'Kidhome', 'Teenhome',
#        'Income(in_$)'],
#       dtype='object')

# %%
cat.columns
# Out:
# Index(['Education', 'Marital_Status', 'Country'], dtype='object')

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %%
w_data.describe().T
# Out:
#                           count                           mean  \
# CustomerID               2216.0                    5588.353339
# AcceptedCmp1             2216.0                       0.064079
# AcceptedCmp2             2216.0                       0.013538
# AcceptedCmp3             2216.0                       0.073556
# AcceptedCmp4             2216.0                       0.074007
# AcceptedCmp5             2216.0                       0.073105
# Response                 2216.0                       0.150271
# Complain                 2216.0                       0.009477
# Recency                  2216.0                      49.012635
# MntWines                 2216.0                     305.091606
# MntFruits                2216.0                      26.356047
# MntMeatProducts          2216.0                     166.995939
# MntFishProducts          2216.0                      37.637635
# MntSweetProducts         2216.0                      27.028881
# MntGoldProds             2216.0                      43.965253
# NumDealsPurchases        2216.0                       2.323556
# NumWebPurchases          2216.0                       4.085289
# NumCatalogPurchases      2216.0                       2.671029
# NumStorePurchases        2216.0                       5.800993
# NumWebVisitsMonth        2216.0                       5.319043
# Year_Birth               2216.0                    1968.820397
# Kidhome                  2216.0                       0.441787
# Teenhome                 2216.0                       0.505415
# Customer_Inseption_Date    2216  2013-07-10 11:29:27.509025280
# Income(in_$)             2216.0                   52247.251354
#
#                                          min                  25%  \
# CustomerID                               0.0              2814.75
# AcceptedCmp1                             0.0                  0.0
# AcceptedCmp2                             0.0                  0.0
# AcceptedCmp3                             0.0                  0.0
# AcceptedCmp4                             0.0                  0.0
# AcceptedCmp5                             0.0                  0.0
# Response                                 0.0                  0.0
# Complain                                 0.0                  0.0
# Recency                                  0.0                 24.0
# MntWines                                 0.0                 24.0
# MntFruits                                0.0                  2.0
# MntMeatProducts                          0.0                 16.0
# MntFishProducts                          0.0                  3.0
# MntSweetProducts                         0.0                  1.0
# MntGoldProds                             0.0                  9.0
# NumDealsPurchases                        0.0                  1.0
# NumWebPurchases                          0.0                  2.0
# NumCatalogPurchases                      0.0                  0.0
# NumStorePurchases                        0.0                  3.0
# NumWebVisitsMonth                        0.0                  3.0
# Year_Birth                            1893.0               1959.0
# Kidhome                                  0.0                  0.0
# Teenhome                                 0.0                  0.0
# Customer_Inseption_Date  2012-07-30 00:00:00  2013-01-16 00:00:00
# Income(in_$)                          1730.0              35303.0
#
#                                          50%                  75%  \
# CustomerID                            5458.5              8421.75
# AcceptedCmp1                             0.0                  0.0
# AcceptedCmp2                             0.0                  0.0
# AcceptedCmp3                             0.0                  0.0
# AcceptedCmp4                             0.0                  0.0
# AcceptedCmp5                             0.0                  0.0
# Response                                 0.0                  0.0
# Complain                                 0.0                  0.0
# Recency                                 49.0                 74.0
# MntWines                               174.5                505.0
# MntFruits                                8.0                 33.0
# MntMeatProducts                         68.0               232.25
# MntFishProducts                         12.0                 50.0
# MntSweetProducts                         8.0                 33.0
# MntGoldProds                            24.5                 56.0
# NumDealsPurchases                        2.0                  3.0
# NumWebPurchases                          4.0                  6.0
# NumCatalogPurchases                      2.0                  4.0
# NumStorePurchases                        5.0                  8.0
# NumWebVisitsMonth                        6.0                  7.0
# Year_Birth                            1970.0               1977.0
# Kidhome                                  0.0                  1.0
# Teenhome                                 0.0                  1.0
# Customer_Inseption_Date  2013-07-08 12:00:00  2013-12-31 00:00:00
# Income(in_$)                         51381.5              68522.0
#
#                                          max           std
# CustomerID                           11191.0   3249.376275
# AcceptedCmp1                             1.0       0.24495
# AcceptedCmp2                             1.0      0.115588
# AcceptedCmp3                             1.0      0.261106
# AcceptedCmp4                             1.0      0.261842
# AcceptedCmp5                             1.0      0.260367
# Response                                 1.0      0.357417
# Complain                                 1.0      0.096907
# Recency                                 99.0     28.948352
# MntWines                              1493.0     337.32792
# MntFruits                              199.0     39.793917
# MntMeatProducts                       1725.0    224.283273
# MntFishProducts                        259.0     54.752082
# MntSweetProducts                       262.0     41.072046
# MntGoldProds                           321.0     51.815414
# NumDealsPurchases                       15.0      1.923716
# NumWebPurchases                         27.0      2.740951
# NumCatalogPurchases                     28.0      2.926734
# NumStorePurchases                       13.0      3.250785
# NumWebVisitsMonth                       20.0      2.425359
# Year_Birth                            1996.0     11.985554
# Kidhome                                  2.0      0.536896
# Teenhome                                 2.0      0.544181
# Customer_Inseption_Date  2014-06-29 00:00:00           NaN
# Income(in_$)                        666666.0  25173.076661

# %%
count.corr()
# Out:
#                      CustomerID  AcceptedCmp1  AcceptedCmp2  AcceptedCmp3  \
# CustomerID             1.000000     -0.018219     -0.014994     -0.035890
# AcceptedCmp1          -0.018219      1.000000      0.176637      0.095683
# AcceptedCmp2          -0.014994      0.176637      1.000000      0.071702
# AcceptedCmp3          -0.035890      0.095683      0.071702      1.000000
# AcceptedCmp4          -0.023933      0.242782      0.295050     -0.079659
# AcceptedCmp5          -0.007064      0.407878      0.222121      0.080248
# Response              -0.021491      0.297345      0.169294      0.254005
# Complain               0.034154     -0.025594     -0.011459      0.008124
# Recency               -0.044376     -0.021061     -0.001400     -0.032257
# MntWines              -0.021084      0.351417      0.206185      0.061463
# MntFruits              0.007326      0.191816     -0.009980      0.014424
# MntMeatProducts       -0.005902      0.313076      0.043521      0.018438
# MntFishProducts       -0.023992      0.261608      0.002345     -0.000219
# MntSweetProducts      -0.005936      0.245102      0.010188      0.001780
# MntGoldProds          -0.011172      0.170132      0.050734      0.124958
# NumDealsPurchases     -0.040612     -0.127374     -0.037981     -0.023135
# NumWebPurchases       -0.018476      0.159292      0.034829      0.042958
# NumCatalogPurchases   -0.002274      0.309026      0.099915      0.104345
# NumStorePurchases     -0.013070      0.178743      0.085271     -0.068913
# NumWebVisitsMonth     -0.007794     -0.194773     -0.007362      0.061307
# Year_Birth             0.002355     -0.009611     -0.006717      0.061784
# Kidhome                0.001736     -0.174163     -0.081868      0.016066
# Teenhome              -0.003030     -0.144855     -0.015521     -0.042522
# Income(in_$)           0.013095      0.276820      0.087545     -0.016174
#
#                      AcceptedCmp4  AcceptedCmp5  Response  Complain   Recency  \
# CustomerID              -0.023933     -0.007064 -0.021491  0.034154 -0.044376
# AcceptedCmp1             0.242782      0.407878  0.297345 -0.025594 -0.021061
# AcceptedCmp2             0.295050      0.222121  0.169294 -0.011459 -0.001400
# AcceptedCmp3            -0.079659      0.080248  0.254005  0.008124 -0.032257
# AcceptedCmp4             1.000000      0.311314  0.180205 -0.027652  0.017566
# AcceptedCmp5             0.311314      1.000000  0.323374 -0.009576 -0.000482
# Response                 0.180205      0.323374  1.000000 -0.002029 -0.199766
# Complain                -0.027652     -0.009576 -0.002029  1.000000  0.013637
# Recency                  0.017566     -0.000482 -0.199766  0.013637  1.000000
# MntWines                 0.373143      0.473550  0.246299 -0.039470  0.015721
# MntFruits                0.006396      0.212871  0.122443 -0.005324 -0.005844
# MntMeatProducts          0.091618      0.376867  0.237746 -0.023782  0.022518
# MntFishProducts          0.016105      0.196277  0.108145 -0.021220  0.000551
# MntSweetProducts         0.029313      0.259230  0.116170 -0.022641  0.025110
# MntGoldProds             0.024015      0.181397  0.140332 -0.031133  0.017663
# NumDealsPurchases        0.016077     -0.184253  0.003451  0.000497  0.002115
# NumWebPurchases          0.162932      0.141189  0.151431 -0.016642 -0.005641
# NumCatalogPurchases      0.140182      0.322471  0.219914 -0.020839  0.024081
# NumStorePurchases        0.178020      0.212954  0.036241 -0.016941 -0.000434
# NumWebVisitsMonth       -0.028666     -0.277883 -0.002209  0.019785 -0.018564
# Year_Birth              -0.066109      0.010575  0.023692 -0.030407 -0.016295
# Kidhome                 -0.162026     -0.205305 -0.077909  0.040978  0.011492
# Teenhome                 0.038376     -0.190791 -0.153901  0.003307  0.013838
# Income(in_$)             0.184400      0.335943  0.133047 -0.027225 -0.003970
#
#                      MntWines  ...  MntGoldProds  NumDealsPurchases  \
# CustomerID          -0.021084  ...     -0.011172          -0.040612
# AcceptedCmp1         0.351417  ...      0.170132          -0.127374
# AcceptedCmp2         0.206185  ...      0.050734          -0.037981
# AcceptedCmp3         0.061463  ...      0.124958          -0.023135
# AcceptedCmp4         0.373143  ...      0.024015           0.016077
# AcceptedCmp5         0.473550  ...      0.181397          -0.184253
# Response             0.246299  ...      0.140332           0.003451
# Complain            -0.039470  ...     -0.031133           0.000497
# Recency              0.015721  ...      0.017663           0.002115
# MntWines             1.000000  ...      0.392731           0.008886
# MntFruits            0.387024  ...      0.396487          -0.134512
# MntMeatProducts      0.568860  ...      0.359446          -0.121308
# MntFishProducts      0.397721  ...      0.427142          -0.143241
# MntSweetProducts     0.390326  ...      0.357450          -0.121432
# MntGoldProds         0.392731  ...      1.000000           0.051905
# NumDealsPurchases    0.008886  ...      0.051905           1.000000
# NumWebPurchases      0.553786  ...      0.407066           0.241440
# NumCatalogPurchases  0.634753  ...      0.442428          -0.012118
# NumStorePurchases    0.640012  ...      0.389180           0.066107
# NumWebVisitsMonth   -0.321978  ...     -0.247691           0.346048
# Year_Birth          -0.159451  ...     -0.064208          -0.058668
# Kidhome             -0.497336  ...     -0.355029           0.216913
# Teenhome             0.003747  ...     -0.019887           0.386246
# Income(in_$)         0.578650  ...      0.325916          -0.083101
#
#                      NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# CustomerID                 -0.018476            -0.002274          -0.013070
# AcceptedCmp1                0.159292             0.309026           0.178743
# AcceptedCmp2                0.034829             0.099915           0.085271
# AcceptedCmp3                0.042958             0.104345          -0.068913
# AcceptedCmp4                0.162932             0.140182           0.178020
# AcceptedCmp5                0.141189             0.322471           0.212954
# Response                    0.151431             0.219914           0.036241
# Complain                   -0.016642            -0.020839          -0.016941
# Recency                    -0.005641             0.024081          -0.000434
# MntWines                    0.553786             0.634753           0.640012
# MntFruits                   0.302039             0.486263           0.458491
# MntMeatProducts             0.307090             0.734127           0.486006
# MntFishProducts             0.299688             0.532757           0.457745
# MntSweetProducts            0.333937             0.495136           0.455225
# MntGoldProds                0.407066             0.442428           0.389180
# NumDealsPurchases           0.241440            -0.012118           0.066107
# NumWebPurchases             1.000000             0.386868           0.516240
# NumCatalogPurchases         0.386868             1.000000           0.517840
# NumStorePurchases           0.516240             0.517840           1.000000
# NumWebVisitsMonth          -0.051226            -0.522004          -0.432398
# Year_Birth                 -0.153051            -0.121764          -0.127891
# Kidhome                    -0.371977            -0.504501          -0.501349
# Teenhome                    0.162077            -0.112692           0.049737
# Income(in_$)                0.387878             0.589162           0.529362
#
#                      NumWebVisitsMonth  Year_Birth   Kidhome  Teenhome  \
# CustomerID                   -0.007794    0.002355  0.001736 -0.003030
# AcceptedCmp1                 -0.194773   -0.009611 -0.174163 -0.144855
# AcceptedCmp2                 -0.007362   -0.006717 -0.081868 -0.015521
# AcceptedCmp3                  0.061307    0.061784  0.016066 -0.042522
# AcceptedCmp4                 -0.028666   -0.066109 -0.162026  0.038376
# AcceptedCmp5                 -0.277883    0.010575 -0.205305 -0.190791
# Response                     -0.002209    0.023692 -0.077909 -0.153901
# Complain                      0.019785   -0.030407  0.040978  0.003307
# Recency                      -0.018564   -0.016295  0.011492  0.013838
# MntWines                     -0.321978   -0.159451 -0.497336  0.003747
# MntFruits                    -0.418729   -0.017747 -0.373396 -0.176558
# MntMeatProducts              -0.539484   -0.033697 -0.439261 -0.261122
# MntFishProducts              -0.446423   -0.040425 -0.388884 -0.205242
# MntSweetProducts             -0.422371   -0.020204 -0.378026 -0.163056
# MntGoldProds                 -0.247691   -0.064208 -0.355029 -0.019887
# NumDealsPurchases             0.346048   -0.058668  0.216913  0.386246
# NumWebPurchases              -0.051226   -0.153051 -0.371977  0.162077
# NumCatalogPurchases          -0.522004   -0.121764 -0.504501 -0.112692
# NumStorePurchases            -0.432398   -0.127891 -0.501349  0.049737
# NumWebVisitsMonth             1.000000    0.123904  0.447477  0.131240
# Year_Birth                    0.123904    1.000000  0.233615 -0.350791
# Kidhome                       0.447477    0.233615  1.000000 -0.039869
# Teenhome                      0.131240   -0.350791 -0.039869  1.000000
# Income(in_$)                 -0.553088   -0.161791 -0.428669  0.019133
#
#                      Income(in_$)
# CustomerID               0.013095
# AcceptedCmp1             0.276820
# AcceptedCmp2             0.087545
# AcceptedCmp3            -0.016174
# AcceptedCmp4             0.184400
# AcceptedCmp5             0.335943
# Response                 0.133047
# Complain                -0.027225
# Recency                 -0.003970
# MntWines                 0.578650
# MntFruits                0.430842
# MntMeatProducts          0.584633
# MntFishProducts          0.438871
# MntSweetProducts         0.440744
# MntGoldProds             0.325916
# NumDealsPurchases       -0.083101
# NumWebPurchases          0.387878
# NumCatalogPurchases      0.589162
# NumStorePurchases        0.529362
# NumWebVisitsMonth       -0.553088
# Year_Birth              -0.161791
# Kidhome                 -0.428669
# Teenhome                 0.019133
# Income(in_$)             1.000000
#
# [24 rows x 24 columns]

# %%
# HeatMap

plt.figure(figsize=(15,5))
sns.heatmap(count.corr(),annot=True)
plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %%
cat.head()
# Out:
#     Education Marital_Status Country
# 0  Graduation       Divorced      SP
# 1  Graduation         Single      CA
# 2  Graduation        Married      US
# 3  Graduation       Together     AUS
# 4  Graduation         Single      SP

# %%
pd.get_dummies(cat)
# Out:
#       Education_2n Cycle  Education_Basic  Education_Graduation  \
# 0                  False            False                  True
# 1                  False            False                  True
# 2                  False            False                  True
# 3                  False            False                  True
# 4                  False            False                  True
# ...                  ...              ...                   ...
# 2211               False            False                 False
# 2212                True            False                 False
# 2213               False            False                  True
# 2214               False            False                  True
# 2215               False            False                 False
#
#       Education_Master  Education_PhD  Marital_Status_Absurd  \
# 0                False          False                  False
# 1                False          False                  False
# 2                False          False                  False
# 3                False          False                  False
# 4                False          False                  False
# ...                ...            ...                    ...
# 2211             False           True                  False
# 2212             False          False                  False
# 2213             False          False                  False
# 2214             False          False                  False
# 2215             False           True                  False
#
#       Marital_Status_Alone  Marital_Status_Divorced  Marital_Status_Married  \
# 0                    False                     True                   False
# 1                    False                    False                   False
# 2                    False                    False                    True
# 3                    False                    False                   False
# 4                    False                    False                   False
# ...                    ...                      ...                     ...
# 2211                 False                     True                   False
# 2212                 False                    False                    True
# 2213                 False                     True                   False
# 2214                 False                    False                    True
# 2215                 False                    False                    True
#
#       Marital_Status_Single  ...  Marital_Status_Widow  Marital_Status_YOLO  \
# 0                     False  ...                 False                False
# 1                      True  ...                 False                False
# 2                     False  ...                 False                False
# 3                     False  ...                 False                False
# 4                      True  ...                 False                False
# ...                     ...  ...                   ...                  ...
# 2211                  False  ...                 False                False
# 2212                  False  ...                 False                False
# 2213                  False  ...                 False                False
# 2214                  False  ...                 False                False
# 2215                  False  ...                 False                False
#
#       Country_AUS  Country_CA  Country_GER  Country_IND  Country_ME  \
# 0           False       False        False        False       False
# 1           False        True        False        False       False
# 2           False       False        False        False       False
# 3            True       False        False        False       False
# 4           False       False        False        False       False
# ...           ...         ...          ...          ...         ...
# 2211        False       False        False        False       False
# 2212        False       False        False        False       False
# 2213        False       False        False        False       False
# 2214        False       False        False         True       False
# 2215        False        True        False        False       False
#
#       Country_SA  Country_SP  Country_US
# 0          False        True       False
# 1          False       False       False
# 2          False       False        True
# 3          False       False       False
# 4          False        True       False
# ...          ...         ...         ...
# 2211       False       False        True
# 2212       False        True       False
# 2213       False        True       False
# 2214       False       False       False
# 2215       False       False       False
#
# [2216 rows x 21 columns]

# %%
# Importing the libraries

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
for i in cat:
    cat[i]=label_encoder.fit_transform(cat[i])

# %%
cat.head()
# Out:
#    Education  Marital_Status  Country
# 0          2               2        6
# 1          2               4        1
# 2          2               3        7
# 3          2               5        0
# 4          2               4        6

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %%
# Histplot

count.hist(figsize=(15,15))
plt.show()

# %%
# Boxplot

for i in count:
    plt.figure(figsize=(10,5))
    sns.boxplot(y=i,data=count)
    plt.show()

# %%
w_data['Response'].value_counts()
# Out:
# Response
# 0    1883
# 1     333
# Name: count, dtype: int64

# %%
count.columns
# Out:
# Index(['CustomerID', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'Year_Birth', 'Kidhome', 'Teenhome',
#        'Income(in_$)'],
#       dtype='object')

# %%
Q1 = count["MntWines"].quantile(0.25)
Q3 = count["MntWines"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_MntWines = count[(count["MntWines"] >= lower_bound) & (count["MntWines"] <= upper_bound)]
outliers_MntWines = count[(count['MntWines'] <= lower_bound) | (count['MntWines'] >= upper_bound)]

# %%
mean_no_outliers_MntWines=np.mean(count['MntWines'])
mean_no_outliers_MntWines
# Out:
# 305.09160649819495

# %%
count.loc[outliers_MntWines.index, 'MntWines'] = mean_no_outliers_MntWines

# %%
Q1 = count["MntFruits"].quantile(0.25)
Q3 = count["MntFruits"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_MntFruits = count[(count["MntFruits"] >= lower_bound) & (count["MntFruits"] <= upper_bound)]
outliers_MntFruits = count[(count["MntFruits"] <= lower_bound) | (count["MntFruits"] >= upper_bound)]

mean_no_outliers_MntFruits=np.mean(count['MntFruits'])
mean_no_outliers_MntFruits
# Out:
# 26.356046931407942

# %%
count.loc[outliers_MntFruits.index, 'MntFruits'] = mean_no_outliers_MntFruits

# %%
Q1 = count["MntMeatProducts"].quantile(0.25)
Q3 = count["MntMeatProducts"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_MntMeatProducts = count[(count["MntMeatProducts"] >= lower_bound) & (count["MntMeatProducts"] <= upper_bound)]
outliers_MntMeatProducts = count[(count["MntMeatProducts"] <= lower_bound) | (count["MntMeatProducts"] >= upper_bound)]

mean_no_outliers_MntMeatProducts=np.mean(count['MntMeatProducts'])
mean_no_outliers_MntMeatProducts
# Out:
# 166.99593862815885

# %%
count.loc[outliers_MntMeatProducts.index, 'MntMeatProducts'] = mean_no_outliers_MntMeatProducts

# %%
Q1 = count["MntFishProducts"].quantile(0.25)
Q3 = count["MntFishProducts"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_MntFishProducts = count[(count["MntFishProducts"] >= lower_bound) & (count["MntFishProducts"] <= upper_bound)]
outliers_MntFishProducts = count[(count["MntFishProducts"] <= lower_bound) | (count["MntFishProducts"] >= upper_bound)]

mean_no_outliers_MntFishProducts=np.mean(count['MntFishProducts'])
mean_no_outliers_MntFishProducts
# Out:
# 37.63763537906137

# %%
count.loc[outliers_MntFishProducts.index, 'MntFishProducts'] = mean_no_outliers_MntFishProducts

# %%
Q1 = count["MntSweetProducts"].quantile(0.25)
Q3 = count["MntSweetProducts"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_MntSweetProducts = count[(count["MntSweetProducts"] >= lower_bound) & (count["MntSweetProducts"] <= upper_bound)]
outliers_MntSweetProducts = count[(count["MntSweetProducts"] <= lower_bound) | (count["MntSweetProducts"] >= upper_bound)]

mean_no_outliers_MntSweetProducts=np.mean(count['MntSweetProducts'])
mean_no_outliers_MntSweetProducts
# Out:
# 27.028880866425993

# %%
count.loc[outliers_MntSweetProducts.index, 'MntSweetProducts'] = mean_no_outliers_MntSweetProducts

# %%
Q1 = count["MntGoldProds"].quantile(0.25)
Q3 = count["MntGoldProds"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_MntGoldProds = count[(count["MntGoldProds"] >= lower_bound) & (count["MntGoldProds"] <= upper_bound)]
outliers_MntGoldProds = count[(count["MntGoldProds"] <= lower_bound) | (count["MntGoldProds"] >= upper_bound)]

mean_no_outliers_MntGoldProds=np.mean(count['MntGoldProds'])
mean_no_outliers_MntGoldProds
# Out:
# 43.96525270758123

# %%
count.loc[outliers_MntGoldProds.index, 'MntGoldProds'] = mean_no_outliers_MntGoldProds

# %%
Q1 = count["NumDealsPurchases"].quantile(0.25)
Q3 = count["NumDealsPurchases"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_NumDealsPurchases = count[(count["NumDealsPurchases"] >= lower_bound) & (count["NumDealsPurchases"] <= upper_bound)]
outliers_NumDealsPurchases = count[(count["NumDealsPurchases"] <= lower_bound) | (count["NumDealsPurchases"] >= upper_bound)]

mean_no_outliers_NumDealsPurchases=np.mean(count['NumDealsPurchases'])
mean_no_outliers_NumDealsPurchases
# Out:
# 2.3235559566787005

# %%
count.loc[outliers_NumDealsPurchases.index, 'NumDealsPurchases'] = mean_no_outliers_NumDealsPurchases

# %%
Q1 = count["NumWebPurchases"].quantile(0.25)
Q3 = count["NumWebPurchases"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_NumWebPurchases = count[(count["NumWebPurchases"] >= lower_bound) & (count["NumWebPurchases"] <= upper_bound)]
outliers_NumWebPurchases = count[(count["NumWebPurchases"] <= lower_bound) | (count["NumWebPurchases"] >= upper_bound)]

mean_no_outliers_NumWebPurchases=np.mean(count['NumWebPurchases'])
mean_no_outliers_NumWebPurchases
# Out:
# 4.08528880866426

# %%
count.loc[outliers_NumWebPurchases.index, 'NumWebPurchases'] = mean_no_outliers_NumWebPurchases

# %%
Q1 = count["NumCatalogPurchases"].quantile(0.25)
Q3 = count["NumCatalogPurchases"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_NumCatalogPurchases = count[(count["NumCatalogPurchases"] >= lower_bound) & (count["NumCatalogPurchases"] <= upper_bound)]
outliers_NumCatalogPurchases = count[(count["NumCatalogPurchases"] <= lower_bound) | (count["NumCatalogPurchases"] >= upper_bound)]

mean_no_outliers_NumCatalogPurchases=np.mean(count['NumCatalogPurchases'])
mean_no_outliers_NumCatalogPurchases
# Out:
# 2.671028880866426

# %%
count.loc[outliers_NumCatalogPurchases.index, 'NumCatalogPurchases'] = mean_no_outliers_NumCatalogPurchases

# %%
Q1 = count["NumWebVisitsMonth"].quantile(0.25)
Q3 = count["NumWebVisitsMonth"].quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the data to remove outliers
no_outliers_NumWebVisitsMonth = count[(count["NumWebVisitsMonth"] >= lower_bound) & (count["NumWebVisitsMonth"] <= upper_bound)]
outliers_NumWebVisitsMonth = count[(count["NumWebVisitsMonth"] <= lower_bound) | (count["NumWebVisitsMonth"] >= upper_bound)]

mean_no_outliers_NumWebVisitsMonth=np.mean(count['NumWebVisitsMonth'])
mean_no_outliers_NumWebVisitsMonth
# Out:
# 5.319043321299639

# %%
count.loc[outliers_NumWebVisitsMonth.index, 'NumWebVisitsMonth'] = mean_no_outliers_NumWebVisitsMonth

# %% [markdown]
# #### Generate and check hypothesis around Amount Spent on different categories and response rate in different marketing campaigns.

# %%
count.columns
# Out:
# Index(['CustomerID', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'Year_Birth', 'Kidhome', 'Teenhome',
#        'Income(in_$)'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Response', y='MntWines', hue='AcceptedCmp1', data=count)
plt.title('Amount Spent on Wines vs. Response Rate in Campaign 1')
plt.xlabel('Response')
plt.ylabel('Amount Spent on Wines')
plt.show()

# %%
from scipy.stats import ttest_ind

# %%
responders = count[count['Response'] == 1]
non_responders = count[count['Response'] == 0]
t_stat, p_value = ttest_ind(responders['MntWines'], non_responders['MntWines'])

print(f"T-statistic: {t_stat}, p-value: {p_value}")
# Out:
# T-statistic: 9.801828324159429, p-value: 3.110140281370847e-22

# %% [markdown]
# #### Create a funnel analysis showing what percentage of unique customers accept campaign 1,2, 3,..etc

# %%
campaigns = ['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5']
unique_customers = count['CustomerID'].nunique()
campaign_acceptance = {}

for campaign in campaigns:
    accepted_customers = count[count[campaign] == 1]['CustomerID'].nunique()
    campaign_acceptance[campaign] = accepted_customers

# %%
funnel_data = {}
for campaign, accepted_customers in campaign_acceptance.items():
    percentage = (accepted_customers / unique_customers) * 100
    funnel_data[campaign] = percentage

# %%
plt.figure(figsize=(10,5))
plt.bar(funnel_data.keys(), funnel_data.values(), color='skyblue')
plt.title('Funnel Analysis of Campaign Acceptance')
plt.xlabel('Campaigns')
plt.ylabel('Percentage of Unique Customers (%)')
plt.ylim(0, 15)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Find out how income impacts the amount spent on - Wine - Meat Products - Gold Products - Fish Products

# %%
product_categories = ['MntWines', 'MntMeatProducts', 'MntGoldProds', 'MntFishProducts']

for category in product_categories:
    plt.figure(figsize=(10, 8))
    sns.scatterplot(data=count, x='Income(in_$)', y=category)
    plt.title(f'Income vs. Amount Spent on {category}')
    plt.xlabel('Income')
    plt.ylabel(f'Amount Spent on {category}')
    plt.show()

# %%
correlation_matrix = count[['Income(in_$)'] + product_categories].corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                  Income(in_$)  MntWines  MntMeatProducts  MntGoldProds  \
# Income(in_$)         1.000000  0.571816         0.553218      0.338427
# MntWines             0.571816  1.000000         0.593524      0.421322
# MntMeatProducts      0.553218  0.593524         1.000000      0.443097
# MntGoldProds         0.338427  0.421322         0.443097      1.000000
# MntFishProducts      0.441246  0.444601         0.601582      0.418386
#
#                  MntFishProducts
# Income(in_$)            0.441246
# MntWines                0.444601
# MntMeatProducts         0.601582
# MntGoldProds            0.418386
# MntFishProducts         1.000000

# %% [markdown]
# #### Can you test the hypothesis that recent customers complain less in general compared to older customers?

# %% [markdown]
# #### Do people who accept the offer in the first campaign also accept in any other campaign?

# %% [markdown]
# #### Profile of people who respond vs. who don’t
